# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
teamsupdated = pd.read_csv("/Users/stephenmcdevitt/Desktop/ds320project/data/TeamsDataUpdated.csv")

# %%
teamsupdated
# Out:
#       yearID lgID teamID franchID divID  Rank    G  Ghome   W   L  ...  \
# 0       1871  NaN    BS1      BNA   NaN     3   31    NaN  20  10  ...
# 1       1871  NaN    CH1      CNA   NaN     2   28    NaN  19   9  ...
# 2       1871  NaN    CL1      CFC   NaN     8   29    NaN  10  19  ...
# 3       1871  NaN    FW1      KEK   NaN     7   19    NaN   7  12  ...
# 4       1871  NaN    NY2      NNA   NaN     5   33    NaN  16  17  ...
# ...      ...  ...    ...      ...   ...   ...  ...    ...  ..  ..  ...
# 2800    2015   NL    LAN      LAD     W     1  162   81.0  92  70  ...
# 2801    2015   NL    SFN      SFG     W     2  162   81.0  84  78  ...
# 2802    2015   NL    ARI      ARI     W     3  162   81.0  79  83  ...
# 2803    2015   NL    SDN      SDP     W     4  162   81.0  74  88  ...
# 2804    2015   NL    COL      COL     W     5  162   81.0  68  94  ...
#
#      teamIDlahman45 teamIDretro Win_percentage Team_Batting_Average  Team_OBP  \
# ...

# %%
numeric_df = teamsupdated.select_dtypes(include='number')

# Calculate correlations with 'team_winning_percentage'
correlations = numeric_df.corr()['Win_percentage'].drop('Win_percentage')
correlations
# Out:
# yearID                  0.033689
# Rank                   -0.837480
# G                       0.118574
# Ghome                   0.035324
# W                       0.771259
# L                      -0.627431
# R                       0.503801
# AB                      0.154257
# H                       0.293805
# 2B                      0.229004
# 3B                      0.171667
# HR                      0.172688
# BB                      0.229333
# SO                     -0.000763
# SB                      0.150517
# CS                      0.022311
# HBP                     0.020585
# SF                      0.297848
# RA                     -0.370723
# ER                     -0.242356
# ERA                    -0.481265
# CG                      0.080523
# SHO                     0.432563
# SV                      0.189980
# IPouts                  0.144975
# HA                     -0.113842
# HRA                    -0.046551
# BBA                    -0.106996
# ...

# %%
plt.figure(figsize=(18, 3))  # wider and a bit taller
sns.heatmap(corr_df, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation with Team Winning Percentage')
plt.xticks(rotation=45, ha='right')  # Rotate x labels
plt.tight_layout()
plt.show()
